# %%
import pandas as pd
import numpy as np
import requests
import bs4 as bs
import urllib.request

# %%
from tmdbv3api import TMDb
import json
tmdb = TMDb()
tmdb.api_key = 'afa6162dcb8366edc491e0d57b27870f'
from tmdbv3api import Movie
tmdb_movie = Movie()

# %%
def get_genre(x):
    genres = []
    result = tmdb_movie.search(x)
    if not result:
        return np.NaN
    else:
        movie_id = result[0].id
        response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key))
        data_json = response.json()
        if data_json['genres']:
                for i in range(0,len(data_json['genres'])):
                    genres.append(data_json['genres'][i]['name'])
                return " ".join(genres)
        else:
              return np.NaN

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
def get_actor(x,n):
    if len((x.split("screenplay); ")[-1]).split(", ")) <= n:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[n])

# %%
def web_scrap(link):
    source = urllib.request.urlopen(link).read()
    soup = bs.BeautifulSoup(source,'lxml')
    tables = soup.find_all('table',class_='wikitable sortable')
    df1 = pd.read_html(str(tables[0]))[0]
    df2 = pd.read_html(str(tables[1]))[0]
    df3 = pd.read_html(str(tables[2]))[0]
    df4 = pd.read_html(str(tables[3]))[0]
    df = df1.append(df2.append(df3.append(df4 , ignore_index= True), ignore_index= True), ignore_index= True)
    df = df[["Title","Cast and crew"]]
    
    df['genres'] = df['Title'].map(lambda x: get_genre(str(x)))
    df['director_name'] = df['Cast and crew'].map(lambda x: get_director(str(x)))
    df['actor_1_name'] = df['Cast and crew'].map(lambda x: get_actor(str(x),0))
    df['actor_2_name'] = df['Cast and crew'].map(lambda x: get_actor(str(x),1))
    df['actor_3_name'] = df['Cast and crew'].map(lambda x: get_actor(str(x),2))
     
    df = df.rename(columns={'Title':'movie_title'})
    df['movie_title'] = df['movie_title'].str.lower()
    df = df[['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]
    df= df.replace(np.nan, 'unknown')
    df['comb'] = df['actor_1_name'] + ' ' + df['actor_2_name'] + ' '+ df['actor_3_name'] + ' '+ df['director_name'] +' ' + df['genres']

    return df

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2018"
df_2018 = web_scrap(link)

# %%
df_2018
# Out:
#           director_name     actor_1_name            actor_2_name  \
# 0          Adam Robitel        Lin Shaye           Angus Sampson
# 1      Lauren Wolkstein    Alex Pettyfer  James Freedson-Jackson
# 2            Simon West   Dominic Cooper          Austin Stowell
# 3      Warwick Thornton      Bryan Brown               Sam Neill
# 4    Jaume Collet-Serra      Liam Neeson            Vera Farmiga
# ..                  ...              ...                     ...
# 269          Etan Cohen     Will Ferrell          John C. Reilly
# 270          Adam McKay   Christian Bale               Amy Adams
# 271          Mimi Leder   Felicity Jones            Armie Hammer
# 272        Karyn Kusama    Nicole Kidman          Sebastian Stan
# 273         David Slade  Fionn Whitehead            Will Poulter
#
#        actor_3_name                                           genres  \
# 0    Leigh Whannell                          Horror Mystery Thriller
# ...

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2019"
df_2019 = web_scrap(link)

# %%
df_2019
# Out:
#               director_name         actor_1_name          actor_2_name  \
# 0              Adam Robitel       Taylor Russell          Logan Miller
# 1               Jen McGowan    Hermione Corfield           Jay Paulson
# 2         Wilson Coneybeare    Donald Sutherland    Vincent Kartheiser
# 3      Charles Martin Smith  Bryce Dallas Howard    Edward James Olmos
# 4               Neil Burger       Bryan Cranston            Kevin Hart
# ..                      ...                  ...                   ...
# 240  Nick Bruno, Troy Quane           Will Smith           Tom Holland
# 241            Greta Gerwig        Saoirse Ronan           Emma Watson
# 242              Sam Mendes        George MacKay  Dean-Charles Chapman
# 243   Destin Daniel Cretton    Michael B. Jordan            Jamie Foxx
# 244         Chinonye Chukwu        Alfre Woodard        Wendell Pierce
#
#          actor_3_name                                    genres  \
# ...

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2020"
df_2020 = web_scrap(link)

# %%
df_2020
# Out:
#         director_name           actor_1_name       actor_2_name  \
# 0       Nicolas Pesce     Andrea Riseborough      Demián Bichir
# 1      William Eubank        Kristen Stewart     Vincent Cassel
# 2       Miguel Arteta        Tiffany Haddish         Rose Byrne
# 3           Jon Avnet           Richard Gere     Peter Dinklage
# 4      Anthony Jerjen          Josh Hartnett  Margarita Levieva
# ..                ...                    ...                ...
# 271  Robert Rodriguez  Priyanka Chopra Jonas       Pedro Pascal
# 272   Paul Greengrass              Tom Hanks      Helena Zengel
# 273       Regina King      Kingsley Ben-Adir          Eli Goree
# 274   Emerald Fennell         Carey Mulligan         Bo Burnham
# 275  Kornél Mundruczó          Vanessa Kirby       Shia LaBeouf
#
#         actor_3_name                          genres            movie_title  \
# 0           John Cho                  Horror Mystery             the grudge
# ...

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2021"
df_2021 = web_scrap(link)

# %%
df_2021
# Out:
#                                          director_name  \
# 0                                       Roseanne Liang
# 1                                        Ramin Bahrani
# 2                                           Doug Liman
# 3                                          Simon Stone
# 4                                      Mikael Håfström
# ..                                                 ...
# 356                                          Joel Coen
# 357                                  Denzel Washington
# 358                                     Erwin brothers
# 359  Apichatpong Weerasethakul (director/acreenplay...
# 360                                                nan
#
#                                           actor_1_name       actor_2_name  \
# 0                                   Chloë Grace Moretz  Taylor John Smith
# 1                                        Adarsh Gourav      Rajkummar Rao
# 2                                        Anne Hathaway   Chiwetel Ejiofor
# ...

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2022"
df_2022 = web_scrap(link)

# %%
df_2022
# Out:
#                             director_name       actor_1_name  \
# 0                           Simon Kinberg   Jessica Chastain
# 1                  Patricia Harris Seeley      Autumn Reeser
# 2                              Asif Akbar      Mickey Rourke
# 3                            Edward Drake  Timothy V. Murphy
# 4    Matt Bettinelli-Olpin, Tyler Gillett    Melissa Barrera
# ..                                    ...                ...
# 325                            Mary Nighy      Anna Kendrick
# 326                                   nan                nan
# 327                                   nan                nan
# 328                                   nan                nan
# 329                                   nan                nan
#
#           actor_2_name     actor_3_name                       genres  \
# 0       Lupita Nyong'o    Penélope Cruz              Action Thriller
# 1         Antonio Cupo      Danny Trejo     Family Animation Fantasy
# ...

# %%
new_df = df_2018.append(df_2019.append(df_2020.append(df_2021.append(df_2022,ignore_index=True),ignore_index=True),ignore_index=True),ignore_index=True)

# %%
new_df
# Out:
#            director_name    actor_1_name            actor_2_name  \
# 0           Adam Robitel       Lin Shaye           Angus Sampson
# 1       Lauren Wolkstein   Alex Pettyfer  James Freedson-Jackson
# 2             Simon West  Dominic Cooper          Austin Stowell
# 3       Warwick Thornton     Bryan Brown               Sam Neill
# 4     Jaume Collet-Serra     Liam Neeson            Vera Farmiga
# ...                  ...             ...                     ...
# 1481          Mary Nighy   Anna Kendrick         Kaniehtiio Horn
# 1482                 nan             nan                 unknown
# 1483                 nan             nan                 unknown
# 1484                 nan             nan                 unknown
# 1485                 nan             nan                 unknown
#
#          actor_3_name                   genres              movie_title  \
# 0      Leigh Whannell  Horror Mystery Thriller  insidious: the last key
# ...

# %%
new_df = new_df[new_df['movie_title'] != "unknown"]

# %%
new_df
# Out:
#            director_name    actor_1_name            actor_2_name  \
# 0           Adam Robitel       Lin Shaye           Angus Sampson
# 1       Lauren Wolkstein   Alex Pettyfer  James Freedson-Jackson
# 2             Simon West  Dominic Cooper          Austin Stowell
# 3       Warwick Thornton     Bryan Brown               Sam Neill
# 4     Jaume Collet-Serra     Liam Neeson            Vera Farmiga
# ...                  ...             ...                     ...
# 1477        Kasi Lemmons     Naomi Ackie           Stanley Tucci
# 1478        Scott Cooper  Christian Bale           Harry Melling
# 1479        Sarah Polley     Rooney Mara              Claire Foy
# 1480        Marc Forster       Tom Hanks         Mariana Treviño
# 1481          Mary Nighy   Anna Kendrick         Kaniehtiio Horn
#
#           actor_3_name                   genres  \
# 0       Leigh Whannell  Horror Mystery Thriller
# 1        Emily Althaus           Thriller Drama
# ...

# %%
old_df = pd.read_csv('Datasets/new_data.csv')

# %%
final_df = old_df.append(new_df,ignore_index=True)

# %%
final_df = final_df[final_df['movie_title'] != "unknown"]

# %%
final_df
# Out:
#           director_name     actor_1_name      actor_2_name  \
# 0         James Cameron      CCH Pounder  Joel David Moore
# 1        Gore Verbinski      Johnny Depp     Orlando Bloom
# 2            Sam Mendes  Christoph Waltz      Rory Kinnear
# 3     Christopher Nolan        Tom Hardy    Christian Bale
# 4           Doug Walker      Doug Walker        Rob Walker
# ...                 ...              ...               ...
# 6841       Kasi Lemmons      Naomi Ackie     Stanley Tucci
# 6842       Scott Cooper   Christian Bale     Harry Melling
# 6843       Sarah Polley      Rooney Mara        Claire Foy
# 6844       Marc Forster        Tom Hanks   Mariana Treviño
# 6845         Mary Nighy    Anna Kendrick   Kaniehtiio Horn
#
#               actor_3_name                           genres  \
# 0                Wes Studi  Action Adventure Fantasy Sci-Fi
# 1           Jack Davenport         Action Adventure Fantasy
# 2         Stephanie Sigman        Action Adventure Thriller
# ...

# %%
final_df.to_csv('Datasets/final_data.csv',index=False)
